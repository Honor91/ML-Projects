# %% [markdown]
# # NBA DATASET

# %% [markdown]
# The dataset contains statistics of 4000 NBA players, including:
#
# - `season`: The season (yearly) the player played in
# - `poss`: Possessions played
# - `mp`: Minutes played
# - `do_ratio`: A player’s ratio of time spent in defense vs. offense; negative values mean more defense positioning
# - `pacing`: Player impact on team possessions per 48 minutes
# - `win_rating`: Wins Above Replacement rating, how many additional wins a player is worth over a same-level replacement

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("https://wagon-public-datasets.s3.amazonaws.com/Machine%20Learning%20Datasets/NBA.csv")

# %%
fig = px.box(df, y=df.columns[1:-2])
fig.show()

# %%
fig = px.histogram(df,x='mp')
fig.show()

# %%
df.head()
# Out:
#    season  poss    mp  do_ratio    pacing  win_rating
# 0    1987  4847  2409 -1.546275 -0.599918    1.643091
# 1    2017  5582  2708  0.996587  0.531888   10.808427
# 2    2016  4976  2407  0.242598  0.127976    3.054773
# 3    2021  1178   585 -1.343806 -1.201034    0.230004
# 4    1988  4534  2056 -1.813990 -0.128997    0.905614

# %%
df.describe()
# Out:
#             season         poss           mp     do_ratio       pacing  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   2001.306750  2781.608750  1379.898500    -1.175324     0.190640
# std      12.515223  2021.057822   998.745215     3.004908     0.840869
# min    1977.000000     1.000000     0.000000   -32.624682    -5.965230
# 25%    1991.000000   960.750000   476.000000    -2.801314    -0.234717
# 50%    2002.000000  2577.000000  1269.000000    -1.153920     0.088102
# 75%    2012.000000  4340.750000  2155.000000     0.533330     0.509212
# max    2021.000000  9271.000000  4270.000000    28.370510    23.732063
#
#         win_rating
# count  4000.000000
# mean      2.044921
# std       3.473775
# min      -5.428715
# 25%      -0.101300
# 50%       0.626639
# 75%       3.233072
# max      26.666873

# %%
# looking for null values
df.isnull().sum()
# Out:
# season        0
# poss          0
# mp            0
# do_ratio      0
# pacing        0
# win_rating    0
# dtype: int64

# %%
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True, cmap = 'viridis');

# %% [markdown]
# ## SIMPLE MODELING

# %%
X = df[['poss','mp']]
y = df['win_rating']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,
                                                 test_size=0.2,
                                                random_state = 0)

# %% [markdown]
# ## Scaling the features

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
